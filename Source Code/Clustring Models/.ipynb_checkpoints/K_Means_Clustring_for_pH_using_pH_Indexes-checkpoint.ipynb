# %% [markdown]
# ### Libraries for dataset manipulation and visulization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Dataset Loading

# %%
dataset = pd.read_csv('C:\\Users\\Mahmood Yousaf\\Desktop\\FYP\\Final-Year-Project-Soil-Analysis-using-machine-learning\\Extracted Features\\Ph_Index_with_Ph_value.csv')

# %% [markdown]
# ### Finding best number of clusters using Elbow Method

# %%
X = dataset.iloc[:, [1,2]].values
print(X)
# Out:
# [[7.03939435e-03 7.90000000e+00]
#  [7.30760094e-03 7.90000000e+00]
#  [6.80585883e-03 7.90000000e+00]
#  ...
#  [8.68003251e-03 7.70000000e+00]
#  [1.76074033e-02 7.70000000e+00]
#  [1.05363631e-02 7.70000000e+00]]

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# C:\Users\Mahmood Yousaf\.conda\envs\gpuEnv\lib\site-packages\sklearn\cluster\_kmeans.py:1039: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(

# %% [markdown]
# ## Training

# %%
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)

# %% [markdown]
# ## Visualising the clusters

# %%
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 100, c = 'pink', label = 'Cluster 4')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters for PH values')
plt.xlabel('PH indexes')
plt.ylabel('PH values')
plt.savefig("KMeansmodelForPHUsingPHIndexes.jpg")
plt.legend()
plt.show()
