# %% [markdown]
# ### Libraries for dataset manipulation and visulization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Dataset Loading

# %%
dataset = pd.read_csv('C:\\Users\\Mahmood Yousaf\\Desktop\\FYP\\Final-Year-Project-Soil-Analysis-using-machine-learning\\Extracted Features\\Formula_Index_with_pH_value.csv')

# %% [markdown]
# ### Finding best number of clusters using Dendogram

# %%
X = dataset.iloc[:, [1,2]].values
print(X)
# Out:
# [[525.    7.9]
#  [505.    7.9]
#  [542.    7.9]
#  ...
#  [397.    7.7]
#  [262.5   7.7]
#  [365.    7.7]]

# %%
import scipy.cluster.hierarchy as sch
dendrogram = sch.dendrogram(sch.linkage(X, method = 'ward'))
plt.title('Dendrogram')
plt.xlabel('Number of observations')
plt.savefig("DendogramForPHValues.jpg")
plt.ylabel('Euclidean distances')
plt.show()

# %% [markdown]
# ## Training

# %%
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters = 2, affinity = 'euclidean', linkage = 'ward')
y_hc = hc.fit_predict(X)

# %% [markdown]
# ## Visualising the clusters

# %%
plt.scatter(X[y_hc == 0, 0], X[y_hc == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_hc == 1, 0], X[y_hc == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.title('Clusters for pH values')
plt.xlabel('Formula Indexes')
plt.ylabel('pH values')
plt.savefig("HCmodelForpHUsingFormula.jpg")
plt.legend()
plt.show()
