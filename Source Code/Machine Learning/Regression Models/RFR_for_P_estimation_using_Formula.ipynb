# %% [markdown]
# ### Libraries for dataset manipulation and visulization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Dataset Loading

# %%
dataset = pd.read_csv('C:\\Users\\Mahmood Yousaf\\Desktop\\FYP\\Final-Year-Project-Soil-Analysis-using-machine-learning\\Extracted Features\\Formula_Index_with_P_value.csv')

# %% [markdown]
# ### Preprocessing on dataset

# %%
X = np.array(dataset['Formula_Index'])
Y = np.array(dataset['P_Value'])
print(X)
print(Y)
# Out:
# [525.  505.  542.  ... 397.  262.5 365. ]
# [5.4 5.4 4.8 ... 5.  5.5 5.5]

# %%
X = X.reshape(len(X),1)
Y = Y.reshape(len(Y),1)
print(X,Y)
# Out:
# [[525. ]
#  [505. ]
#  [542. ]
#  ...
#  [397. ]
#  [262.5]
#  [365. ]] [[5.4]
#  [5.4]
#  [4.8]
#  ...
#  [5. ]
#  [5.5]
#  [5.5]]

# %% [markdown]
# ### DTR model training

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, Y)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
regressor = RandomForestRegressor(n_estimators=100, random_state = 0)
regressor.fit(X_train,y_train)
# Out:
# C:\Users\MAHMOO~1\AppData\Local\Temp/ipykernel_13952/3116153416.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(X_train,y_train)
# RandomForestRegressor(random_state=0)

# %% [markdown]
# ### Prediction

# %%
prediction = regressor.predict([[500]])
print(prediction)
# Out:
# [5.33485]

# %%
pred = regressor.predict(X_val)
print(pred)
# Out:
# [4.90538333 4.37429631 5.2870635  5.15283095 6.15062262 6.66305256
#  5.2870635  4.66290422 4.63861667 6.06473571 5.35552659 5.99168185
#  5.57128996 5.38833333 4.32253333 6.84279068 6.94359524 5.15761042
#  4.48378333 5.107      4.94844235 5.40922381 5.903      5.10809405
#  5.99724841 6.66305256 5.0937188  5.65535714 5.29907817 4.84851627
#  4.412      6.37409524 4.72853063 5.0599588  5.0599588  5.01412666
#  5.66924017 5.57128996 4.96466667 6.0444     5.78463095 5.2870635
#  5.91466667 6.37409524 5.026      6.55362538 5.64909206 4.13877222
#  4.82274762 5.0669786  4.6582619  5.2870635  5.10809405 5.7615
#  4.63985714 5.09227143 5.41176265 4.236      4.94844235 5.14
#  4.55961667 6.31585595 5.8650119  5.75760794 5.0669786  6.84279068
#  4.48369524 5.35764235 5.17981548 6.06702021 7.09551373 4.88116667
#  4.1355     6.94359524 6.57906746 6.84279068 4.26909167 4.55961667
#  4.61245    6.55362538 4.078      5.35552659 4.69142656 5.15283095
#  6.31372143 5.10809405 4.44521905 4.66290422 5.0599588  5.0768354
#  4.29777933 5.79297619 5.28433333 5.66924017 4.74273333 5.05949762
#  5.0768354  3.8498     5.12763333 4.84000996 4.83548524 5.28862673
#  4.47129762 3.30848889 5.7410206  6.66305256 4.26909167 4.75536905
#  5.7615     6.7120816  6.76488095 5.66996359 5.2870635  4.19089524
#  5.2870635  5.64368183 5.56591905 4.75199603 5.38833333 4.6582619
#  5.32465556 4.66290422 5.45542857 5.8650119  5.2870635  5.88249453
#  5.20488651 5.66924017 4.17298651 4.86103929 4.7188132  4.805
#  3.62726667 6.67338452 4.39612143 4.84851627 4.69142656 7.23332381
#  4.82274762 4.63985714 5.75729762 4.86374405 4.90538333 5.66216905
#  4.7188132  5.0768354  5.67019048 5.28862673 5.28433333 5.66996359
#  6.0250873  5.64368183 6.31585595 5.17981548 4.14       5.75760794
#  4.6095     4.26909167 6.40066667 5.98932262 5.64368183 5.91466667
#  5.17981548 5.0599588  5.40922381 5.4960381  4.26909167 4.82274762
#  6.31585595 6.36095714 7.07899661 4.5796619  5.98379524 5.01412666
#  5.31461757 5.35764235 6.20515833 3.62726667 4.83548524 5.66996359
#  6.06702021 5.05949762 6.57906746 4.55171905 5.87144037 5.15761042
#  5.35764235 4.26193333 4.63985714 5.99168185 4.39612143 6.58719298
#  5.43929048 5.01412666 5.57128996 5.98932262 4.25356667 4.94025
#  5.40715119 4.39612143 4.29777933 5.45542857 5.3803619  5.05949762
#  5.2062246  5.89387231 6.54802222 5.28862673 5.15761042 5.15761042
#  5.87144037 5.04875    5.40715119 6.31585595 5.03       5.7909
#  5.98379524 4.35195779 4.26193333 5.3803619  5.01412666 5.35764235
#  4.078      4.17298651 4.80782424 5.0609786  5.31461757 7.86780714
#  4.58674325 4.86374405 3.62726667 5.33485    5.26657857 4.43125
#  5.3766     5.66216905 4.1355     4.74833333 5.99168185 4.34731429
#  5.40922381 4.69142656 5.3803619  5.66996359 5.366      6.15062262
#  4.13877222 5.54297381 4.39612143 5.37078879 4.96939915 4.61245
#  5.54455952 5.3803619  6.84279068 7.09551373 4.6442381  4.7188132
#  5.45542857 4.98727857 5.35165    4.96939915 5.77242802 3.8645
#  4.25356667 4.88116667]

# %%
# mse , mae and r2_score values
mae_value = mean_absolute_error(y_val, pred)
mse_value = mean_squared_error(y_val, pred)
r2_score_value = r2_score(y_val, pred)
# Total error with mse , mae and r2_score
print(f"MSE {mse_value}")
print(f"MAE {mae_value}")
print(f"r2_score {r2_score_value}")
# Out:
# MSE 1.9156176882767681
# MAE 1.0588917504724737
# r2_score -0.1974404444645077

# %% [markdown]
# ### Visulization

# %%
plt.plot(pred,color = 'Blue')
plt.plot(y_val, color = 'red')
plt.title("Random Forest Regression Model For P")
plt.legend(['Predicted P values', 'Actual P Values'], loc='upper left')
plt.xlabel('Number of samples')
plt.ylabel('P values')
plt.savefig("RFRmodelForPestimationUsingFormula.jpg")

# %%
from sklearn.metrics import r2_score
r2_score(y_val,pred)
# Out:
# -0.1974404444645077

# %%
print(pred)
# Out:
# [4.90538333 4.37429631 5.2870635  5.15283095 6.15062262 6.66305256
#  5.2870635  4.66290422 4.63861667 6.06473571 5.35552659 5.99168185
#  5.57128996 5.38833333 4.32253333 6.84279068 6.94359524 5.15761042
#  4.13877222 5.54297381 4.39612143 5.37078879 4.96939915 4.61245
#  5.54455952 5.3803619  6.84279068 7.09551373 4.6442381  4.7188132
#  5.45542857 4.98727857 5.35165    4.96939915 5.77242802 3.8645
#  4.25356667 4.88116667]

# %%
print(y_val)
# Out:
# [[ 5.7]
#  [ 5.5]
#  [ 4.6]
#  [ 5.3]
#  [ 5.3]
#  [ 5.5]
#  [ 4.6]
#  [ 4.8]
#  [ 4.7]
#  [ 4.8]
#  [ 4.1]
#  [ 4.1]
#  [ 5.4]
#  [ 5.7]
#  [ 4.5]
#  [ 8. ]
#  [ 5.5]
#  [ 5.8]
#  [ 5.2]
#  [ 5.1]
#  [ 7.4]
#  [ 5.1]
#  [ 6.1]
#  [ 5.8]
#  [ 4. ]
#  [ 6.2]
#  [ 5.6]
#  [ 7.5]
#  [ 4.2]
#  [ 4.8]
#  [ 7.2]
#  [ 3.6]
#  [ 4.6]
#  [ 5.2]
#  [ 4.3]
#  [ 4.8]
#  [ 5.4]
#  [ 6.8]
#  [ 5. ]
#  [ 4.2]
#  [ 4.3]
#  [ 3.7]
#  [ 4.5]
#  [ 8. ]
#  [ 5. ]
#  [ 5.1]
#  [ 4.9]
#  [ 5.1]
#  [ 4.5]
#  [ 6.1]
#  [ 4. ]
#  [ 6.2]
#  [ 6.6]
#  [ 3.8]
#  [ 5.5]
#  [ 5.4]
#  [ 4.8]
#  [ 4. ]
#  [ 5.5]
#  [ 5.5]
#  [ 4. ]
#  [ 4.5]
#  [ 4.5]
#  [ 4.6]
#  [ 4.4]
#  [ 4.8]
#  [ 4. ]
#  [ 5. ]
#  [ 4.8]
#  [ 4.6]
#  [ 5. ]
#  [ 6. ]
#  [ 5.1]
#  [ 6.2]
#  [ 6. ]
#  [ 4.3]
#  [ 4.7]
#  [ 5.2]
#  [ 4.5]
#  [ 8.4]
#  [ 5.5]
#  [ 4.5]
#  [ 4. ]
#  [ 5.3]
#  [ 4.1]
#  [ 5.1]
#  [ 5.5]
#  [ 5.7]
#  [ 3.1]
#  [ 6.8]
#  [ 8.2]
#  [ 5.5]
#  [ 6. ]
#  [ 5.5]
#  [ 4.8]
#  [ 4.2]
#  [ 5.1]
#  [ 4.7]
#  [ 4.8]
#  [ 4.1]
#  [ 4.5]
#  [ 6. ]
#  [ 5. ]
#  [ 4.4]
#  [ 6.1]
#  [ 4.5]
#  [ 4.6]
#  [ 4.6]
#  [ 6.6]
#  [ 6.7]
#  [ 8.3]
#  [ 4. ]
#  [ 6.2]
#  [ 8.8]
#  [ 4.6]
#  [ 4.3]
#  [ 6.2]
#  [ 6.6]
#  [ 5.1]
#  [ 3.8]
#  [ 5.2]
#  [ 6. ]
#  [ 4.1]
#  [ 4.6]
#  [ 4.2]
#  [ 7.1]
#  [ 4.9]
#  [ 4.9]
#  [ 5.2]
#  [ 4.1]
#  [ 3.1]
#  [ 5.5]
#  [ 5.2]
#  [ 4. ]
#  [ 4.8]
#  [ 4. ]
#  [ 4.5]
#  [ 8.1]
#  [ 6.5]
#  [ 4.2]
#  [ 5.5]
#  [ 4. ]
#  [ 3.5]
#  [ 5.5]
#  [ 7.5]
#  [ 5.1]
#  [ 5.1]
#  [ 6.9]
#  [ 4. ]
#  [ 5.5]
#  [ 7. ]
#  [ 4.6]
#  [ 4.9]
#  [ 4.8]
#  [ 5.4]
#  [ 6.2]
#  [ 4. ]
#  [ 9. ]
#  [ 3.7]
#  [ 4.7]
#  [ 3.2]
#  [ 4.7]
#  [ 4.2]
#  [ 4.3]
#  [ 5.7]
#  [ 5. ]
#  [ 6.2]
#  [ 5.1]
#  [ 5.2]
#  [ 5.7]
#  [ 8.1]
#  [ 5.6]
#  [ 8.8]
#  [ 4.1]
#  [ 4.8]
#  [ 4.2]
#  [ 4.8]
#  [ 5.2]
#  [ 4.6]
#  [ 6. ]
#  [ 4.6]
#  [ 7.5]
#  [ 7.1]
#  [ 3.1]
#  [ 5.2]
#  [ 3.5]
#  [ 7.2]
#  [ 5.2]
#  [ 4.8]
#  [ 7.4]
#  [ 5. ]
#  [ 5.6]
#  [ 4.2]
#  [ 5.5]
#  [ 5.8]
#  [ 4.3]
#  [ 5. ]
#  [ 6. ]
#  [ 4.2]
#  [ 4.8]
#  [ 3. ]
#  [ 7.5]
#  [ 4.7]
#  [ 5. ]
#  [ 5.8]
#  [ 7. ]
#  [ 4.4]
#  [ 5.7]
#  [ 5.8]
#  [ 5.6]
#  [ 5. ]
#  [ 6. ]
#  [ 3. ]
#  [ 6. ]
#  [ 5.2]
#  [ 4.4]
#  [ 4. ]
#  [ 6.5]
#  [ 4.6]
#  [ 4.8]
#  [ 4.8]
#  [ 5.5]
#  [ 8.5]
#  [ 4. ]
#  [ 4.3]
#  [ 4.7]
#  [ 8.2]
#  [ 4.2]
#  [ 5.7]
#  [ 4.8]
#  [ 4.2]
#  [ 6.5]
#  [ 5.2]
#  [ 3.6]
#  [ 3.9]
#  [ 7.2]
#  [ 5.1]
#  [ 5.7]
#  [ 5.5]
#  [ 5. ]
#  [ 5. ]
#  [ 5.3]
#  [ 3.8]
#  [ 8.8]
#  [ 5.4]
#  [10.2]
#  [ 8.8]
#  [ 4.5]
#  [ 5. ]
#  [ 4.5]
#  [ 4. ]
#  [ 5. ]
#  [ 5. ]
#  [ 6. ]
#  [ 4.1]
#  [ 9.5]
#  [ 5.2]
#  [ 3.2]
#  [ 7.5]
#  [ 4.8]
#  [ 5. ]
#  [ 4.1]
#  [ 5.8]
#  [ 7.4]
#  [ 7.2]
#  [ 6. ]]
