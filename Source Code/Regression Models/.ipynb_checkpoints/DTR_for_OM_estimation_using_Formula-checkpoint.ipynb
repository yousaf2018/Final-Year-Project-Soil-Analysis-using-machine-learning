# %% [markdown]
# ### Libraries for dataset manipulation and visulization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Dataset Loading

# %%
dataset = pd.read_csv('C:\\Users\\Mahmood Yousaf\\Desktop\\FYP\\Final-Year-Project-Soil-Analysis-using-machine-learning\\Extracted Features\\Formula_Index_with_OM_value.csv')

# %% [markdown]
# ### Preprocessing on dataset

# %%
X = np.array(dataset['Formula_Index'])
Y = np.array(dataset['OM_Value'])
print(X)
print(Y)
# Out:
# [525.  505.  542.  ... 397.  262.5 365. ]
# [0.52 0.52 0.59 ... 0.6  0.5  0.5 ]

# %%
X = X.reshape(len(X),1)
Y = Y.reshape(len(Y),1)
print(X,Y)
# Out:
# [[525. ]
#  [505. ]
#  [542. ]
#  ...
#  [397. ]
#  [262.5]
#  [365. ]] [[0.52]
#  [0.52]
#  [0.59]
#  ...
#  [0.6 ]
#  [0.5 ]
#  [0.5 ]]

# %% [markdown]
# ### DTR model training

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, Y)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %% [markdown]
# ### Prediction

# %%
pred = regressor.predict(X_val)
print(pred)
# Out:
# [0.605      0.58       0.36       0.50571429 0.69       0.4
#  0.53333333 0.78       0.515      0.48833333 0.54333333 0.4975
#  0.53333333 0.62       0.60333333 0.26       0.464      0.4725
#  0.53       0.51666667 0.47666667 0.54666667 0.5425     0.53333333
#  0.38333333 0.585      0.46       0.472      0.53       0.502
#  0.47       0.52       0.83       0.48888889 0.59       0.464
#  0.51       0.60666667 0.504      0.605      0.36666667 0.425
#  0.565      0.4        0.566      0.48222222 0.465      0.465
#  0.566      0.472      0.48       0.395      0.53333333 0.67
#  0.515      0.62       0.4        0.54333333 0.64       0.6
#  0.76       0.46       0.665      0.51333333 0.52111111 0.51
#  0.465      0.47       0.48222222 0.59833333 0.6        0.685
#  0.6        0.57333333 0.57       0.4725     0.52111111 0.60666667
#  0.51       0.46       0.46       0.48833333 0.52       0.52
#  0.48333333 0.51       0.4        0.5        0.50230769 0.5425
#  0.6        0.6        0.52       0.57       0.50571429 0.51666667
#  0.51       0.64       0.51       0.5        0.57       0.45625
#  0.425      0.6        0.5425     0.52111111 0.45625    0.47
#  0.435      0.36       0.395      0.51666667 0.472      0.43666667
#  0.50230769 0.48222222 0.605      0.57       0.36666667 0.36
#  0.57       0.51666667 0.5        0.37333333 0.5        0.51
#  0.83       0.4        0.50230769 0.55       0.54666667 0.55
#  0.566      0.475      0.5        0.45       0.60666667 0.51
#  0.62       0.5425     0.59666667 0.565      0.665      0.50571429
#  0.535      0.64       0.37333333 0.635      0.39       0.472
#  0.46       0.49666667 0.62       0.45       0.52       0.60333333
#  0.43666667 0.5        0.5        0.50230769 0.4        0.56833333
#  0.47888889 0.43666667 0.45625    0.544      0.59       0.665
#  0.54       0.464      0.46       0.565      0.464      0.618
#  0.49       0.46       0.472      0.53       0.46       0.49285714
#  0.56833333 0.36       0.4        0.64       0.566      0.67
#  0.36       0.5        0.63       0.38333333 0.552      0.51
#  0.475      0.72       0.485      0.504      0.6        0.38
#  0.475      0.4        0.49285714 0.4475     0.46666667 0.52
#  0.50230769 0.42       0.472      0.4475     0.8        0.544
#  0.4725     0.55166667 0.6        0.59833333 0.50230769 0.60666667
#  0.47       0.59571429 0.528      0.60333333 0.53       0.5
#  0.58       0.37333333 0.52111111 0.50230769 0.42       0.47
#  0.48833333 0.425      0.59571429 0.4        0.6        0.37333333
#  0.62       0.52       0.48333333 0.425      0.57       0.4975
#  0.51       0.43666667 0.34333333 0.5575     0.54666667 0.6025
#  0.544      0.425      0.41333333 0.68       0.60333333 0.50230769
#  0.415      0.47666667 0.5        0.485      0.6        0.58333333
#  0.6        0.57       0.605      0.38333333 0.52       0.545
#  0.45       0.565     ]

# %%
# mse , mae and r2_score values
mae_value = mean_absolute_error(y_val, pred)
mse_value = mean_squared_error(y_val, pred)
r2_score_value = r2_score(y_val, pred)
# Total error with mse , mae and r2_score
print(f"MSE {mse_value}")
print(f"MAE {mae_value}")
print(f"r2_score {r2_score_value}")
# Out:
# MSE 0.02775811495466908
# MAE 0.1283122997512095
# r2_score -0.3786842526038918

# %% [markdown]
# ### Visulization

# %%
plt.plot(pred,color = 'Blue')
plt.plot(y_val, color = 'red')
plt.title("Decision Tree Regression Model For OM")
plt.legend(['Predicted OM values', 'Actual OM Values'], loc='upper left')
plt.xlabel('Number of samples')
plt.ylabel('OM values')
plt.savefig("DTRmodelForOMestimationUsingFormula.jpg")
