# %% [markdown]
# ### Libraries for dataset manipulation and visulization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Dataset Loading

# %%
dataset = pd.read_csv('C:\\Users\\Mahmood Yousaf\\Desktop\\FYP\\Final-Year-Project-Soil-Analysis-using-machine-learning\\Extracted Features\\Formula_Index_with_OM_value.csv')

# %% [markdown]
# ### Preprocessing on dataset

# %%
X = np.array(dataset['Formula_Index'])
Y = np.array(dataset['OM_Value'])
print(X)
print(Y)
# Out:
# [525.  505.  542.  ... 397.  262.5 365. ]
# [0.52 0.52 0.59 ... 0.6  0.5  0.5 ]

# %%
X = X.reshape(len(X),1)
Y = Y.reshape(len(Y),1)
print(X,Y)
# Out:
# [[525. ]
#  [505. ]
#  [542. ]
#  ...
#  [397. ]
#  [262.5]
#  [365. ]] [[0.52]
#  [0.52]
#  [0.59]
#  ...
#  [0.6 ]
#  [0.5 ]
#  [0.5 ]]

# %% [markdown]
# ### DTR model training

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, Y)

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %% [markdown]
# ### Prediction

# %%
prediction = regressor.predict(X_val)
print(prediction)
# Out:
# [0.59666667 0.6        0.42       0.535      0.545      0.52666667
#  0.5        0.51142857 0.49333333 0.476      0.72       0.42
#  0.59       0.555      0.47       0.72       0.4        0.59666667
#  0.585      0.46       0.47       0.625      0.50230769 0.52
#  0.51125    0.45333333 0.545      0.42       0.45333333 0.5775
#  0.57666667 0.74333333 0.64       0.51125    0.3975     0.69
#  0.505      0.62       0.46       0.63       0.545      0.61
#  0.62       0.5775     0.548      0.49333333 0.465      0.50555556
#  0.59666667 0.50230769 0.495      0.31       0.63       0.49333333
#  0.46666667 0.57666667 0.465      0.41666667 0.43       0.715
#  0.45       0.575      0.502      0.45666667 0.5        0.4875
#  0.615      0.625      0.3975     0.4275     0.42       0.49
#  1.01       0.57       0.5775     0.465      0.495      0.565
#  0.605      0.4425     0.50333333 0.475      0.42       0.74333333
#  0.49166667 0.4075     0.48333333 0.47666667 0.53       0.50230769
#  0.48       0.45333333 0.5        0.514      0.57125    0.62
#  0.54       0.47       0.6        0.38       0.58111111 0.50666667
#  0.64       0.48333333 0.64       0.62       0.59666667 0.62
#  0.57333333 0.69       0.538      0.46       0.5        0.465
#  0.465      0.466      0.51       0.50230769 0.536      0.4575
#  0.53833333 0.62333333 0.52       0.59       0.495      0.42
#  0.52       0.6        0.50230769 0.43       0.55       0.51142857
#  0.62       0.555      0.36       0.476      0.4075     0.57333333
#  0.48       0.56       0.50666667 0.585      0.531      0.4
#  0.38       0.52       0.50333333 0.65       0.52666667 0.3975
#  0.59666667 0.7        0.42       0.5        0.54       0.6
#  0.545      0.52       0.59666667 0.5975     0.7        0.48
#  0.54       0.57       0.4575     0.49       0.538      0.57666667
#  0.72       0.50333333 0.548      0.64       0.466      0.43
#  0.48       0.55       0.59       0.49333333 0.36       0.6
#  0.64       0.51666667 0.51125    0.605      0.4075     0.52
#  0.57333333 0.51       0.69       0.5        0.5        0.536
#  0.31       0.50230769 0.64       0.476      0.64       0.5
#  0.531      0.88       0.51666667 0.575      0.465      0.555
#  0.535      0.562      0.62       0.62333333 0.53       0.531
#  0.62333333 0.535      0.42       0.47666667 0.484      0.5975
#  0.466      0.54       0.7        0.58666667 0.62       0.48333333
#  0.47       0.50230769 0.4075     0.64       0.50666667 0.36
#  0.74333333 0.52       0.53833333 0.48333333 0.45       0.62
#  0.4075     0.58111111 0.62       0.45       0.50230769 0.51
#  0.466      0.5075     0.72       0.485      0.45       0.41666667
#  0.536      0.37166667 0.455      0.47       0.355      0.49166667
#  0.45       0.4        0.50555556 0.575      0.52       0.545
#  0.645      0.49666667 0.50666667 0.74333333 0.72       0.51125
#  0.45333333 0.715     ]

# %% [markdown]
# ### Visulization

# %%
plt.plot(prediction,color = 'Blue')
plt.plot(y_val, color = 'red')
plt.title("Decision Tree Regression Model For OM")
plt.legend(['Predicted OM values', 'Actual OM Values'], loc='upper left')
plt.xlabel('PH indexes')
plt.ylabel('OM values')
plt.savefig("DTRmodelForOMestimationUsingFormula.jpg")
