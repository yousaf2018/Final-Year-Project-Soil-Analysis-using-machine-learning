# %% [markdown]
# ### Libraries for dataset manipulation and visulization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Dataset Loading

# %%
dataset = pd.read_csv('C:\\Users\\Mahmood Yousaf\\Desktop\\FYP\\Final-Year-Project-Soil-Analysis-using-machine-learning\\Extracted Features\\Formula_Index_with_OM_value.csv')

# %% [markdown]
# ### Preprocessing on dataset

# %%
X = np.array(dataset['Formula_Index'])
Y = np.array(dataset['OM_Value'])
print(X)
print(Y)
# Out:
# [525.  505.  542.  ... 397.  262.5 365. ]
# [0.52 0.52 0.59 ... 0.6  0.5  0.5 ]

# %%
X = X.reshape(len(X),1)
Y = Y.reshape(len(Y),1)
print(X,Y)
# Out:
# [[525. ]
#  [505. ]
#  [542. ]
#  ...
#  [397. ]
#  [262.5]
#  [365. ]] [[0.52]
#  [0.52]
#  [0.59]
#  ...
#  [0.6 ]
#  [0.5 ]
#  [0.5 ]]

# %% [markdown]
# ### DTR model training

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, Y)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %% [markdown]
# ### Prediction

# %%
pred = regressor.predict(X_val)
print(pred)
# Out:
# [0.51777778 0.54       0.54       0.47       0.4        0.505
#  0.42333333 0.46714286 0.54833333 0.585      0.45       0.4925
#  0.45       0.5325     0.496      0.72       0.5        0.48
#  0.566      0.475      0.4        0.62       0.50333333 0.45
#  0.63333333 0.54625    0.46333333 0.625      0.6        0.59
#  0.42333333 0.7        0.5        0.46333333 0.566      0.45
#  0.4925     0.43333333 0.43       0.61875    0.605      0.486
#  0.49375    0.5325     0.57333333 0.535      0.49466667 0.54333333
#  0.46333333 0.51       0.4925     0.595      0.665      0.596
#  0.5        0.45       0.51333333 1.09       0.566      0.5125
#  0.58       0.43       0.85       0.54333333 0.4925     0.5
#  0.605      0.51       0.57333333 0.6875     0.565      0.49375
#  0.62333333 0.52       0.48285714 0.51       0.5        0.58
#  0.54       0.26       0.4825     0.42333333 0.505      0.505
#  0.575      0.49       0.4925     0.54833333 0.5025     0.57166667
#  0.26       0.43       0.54666667 0.645      0.54666667 0.53666667
#  0.505      0.64       0.5        0.48333333 0.55166667 0.6875
#  0.592      0.39375    0.665      0.515      0.7        0.64
#  0.3675     0.465      0.605      0.528      0.48833333 0.63333333
#  0.51777778 0.5925     0.57       0.49466667 0.5        0.52
#  0.45       0.5        0.49222222 0.625      0.4        0.48285714
#  0.45333333 0.52625    0.54666667 0.463      0.42       0.61
#  0.486      0.47       0.5        0.63333333 0.46666667 0.45428571
#  0.78       0.496      0.426      0.45333333 0.44       0.46714286
#  0.57       0.39375    0.41333333 0.69333333 0.61875    0.51
#  0.47833333 0.57333333 0.6        0.4        0.7025     0.505
#  0.72       0.4        0.45428571 0.62333333 0.49466667 0.51
#  0.5        0.49222222 0.5        0.565      0.565      0.5
#  0.496      0.4        0.44428571 0.4925     0.645      0.596
#  0.6        0.45       0.5125     0.57285714 0.7        0.435
#  0.546      0.48       0.52625    0.4925     0.6        0.54666667
#  0.47833333 0.39375    0.50333333 0.63       0.4        0.57285714
#  0.44428571 0.463      0.395      0.51333333 0.41333333 0.48833333
#  0.51       0.61       0.51       0.72       0.44428571 0.62333333
#  0.49466667 0.496      0.58333333 0.57       0.68       0.39
#  0.64       0.48       0.48666667 0.48888889 0.72       0.5
#  0.426      0.51       0.565      0.42       0.63       0.4925
#  0.51333333 0.57333333 0.53333333 0.64       0.49222222 0.54
#  0.496      0.54833333 0.645      0.46714286 0.50666667 0.685
#  0.46333333 0.395      0.3675     0.6        0.3675     0.53333333
#  0.63333333 0.5        0.51       0.49375    0.4        0.51333333
#  0.63       0.51       0.47833333 0.66       0.6875     0.55
#  0.546      0.49222222 0.52625    0.49466667 0.6        0.49466667
#  0.435      0.51       0.5        0.4        0.546      0.57
#  0.57333333 0.7025    ]

# %%
# mse , mae and r2_score values
mae_value = mean_absolute_error(y_val, pred)
mse_value = mean_squared_error(y_val, pred)
r2_score_value = r2_score(y_val, pred)
# Total error with mse , mae and r2_score
print(f"MSE {mse_value}")
print(f"MAE {mae_value}")
print(f"r2_score {r2_score_value}")
# Out:
# MSE 0.024093755439714176
# MAE 0.11995948203842939
# r2_score -0.3391853752673839

# %% [markdown]
# ### Visulization

# %%
plt.plot(pred,color = 'Blue')
plt.plot(y_val, color = 'red')
plt.title("Decision Tree Regression Model For OM")
plt.legend(['Predicted OM values', 'Actual OM Values'], loc='upper left')
plt.xlabel('PH indexes')
plt.ylabel('OM values')
plt.savefig("DTRmodelForOMestimationUsingFormula.jpg")
