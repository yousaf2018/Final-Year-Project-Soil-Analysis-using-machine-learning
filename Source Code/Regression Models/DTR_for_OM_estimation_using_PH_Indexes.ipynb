# %% [markdown]
# ### Libraries for dataset manipulation and visulization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Dataset Loading

# %%
dataset = pd.read_csv('C:\\Users\\Mahmood Yousaf\\Desktop\\FYP\\Final-Year-Project-Soil-Analysis-using-machine-learning\\Extracted Features\\pH_Index_with_OM_value.csv')

# %% [markdown]
# ### Preprocessing on dataset

# %%
X = np.array(dataset['pH_Index'])
Y = np.array(dataset['OM_Value'])
print(X)
print(Y)
# Out:
# [0.00703939 0.0073076  0.00680586 ... 0.00868003 0.0176074  0.01053636]
# [0.52 0.52 0.59 ... 0.6  0.5  0.5 ]

# %%
X = X.reshape(len(X),1)
Y = Y.reshape(len(Y),1)
print(X,Y)
# Out:
# [[0.00703939]
#  [0.0073076 ]
#  [0.00680586]
#  ...
#  [0.00868003]
#  [0.0176074 ]
#  [0.01053636]] [[0.52]
#  [0.52]
#  [0.59]
#  ...
#  [0.6 ]
#  [0.5 ]
#  [0.5 ]]

# %% [markdown]
# ### DTR model training

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, Y)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %% [markdown]
# ### Prediction

# %%
prediction = regressor.predict(X_val)
print(prediction)
# Out:
# [0.56  0.6   0.5   0.565 0.62  0.4   0.4   0.5   0.57  0.64  0.26  0.44
#  0.6   0.69  0.5   0.6   0.6   0.52  0.4   0.78  0.46  0.67  0.54  0.5
#  0.5   0.45  0.6   0.71  0.49  0.6   0.5   0.7   0.34  0.5   0.6   0.3
#  0.26  0.7   0.62  0.7   0.4   0.44  0.5   0.83  0.48  0.6   0.55  0.76
#  0.4   0.72  0.5   0.3   0.67  0.3   0.6   0.62  0.78  0.26  0.4   0.5
#  0.6   0.5   0.49  0.41  0.5   0.21  0.72  0.6   0.52  0.74  0.43  0.47
#  0.69  0.52  0.45  0.5   0.46  0.565 0.49  0.38  0.45  0.55  0.47  0.7
#  0.59  0.4   0.46  0.5   0.5   0.6   0.6   0.5   0.57  0.61  0.69  0.72
#  0.5   0.2   1.    0.34  0.6   0.4   0.6   0.61  0.62  0.4   0.7   0.19
#  0.53  0.48  0.77  0.42  0.69  0.4   0.5   0.48  0.3   0.5   0.7   0.52
#  0.6   0.5   0.4   0.72  0.7   0.3   0.365 0.69  0.4   0.43  0.36  0.4
#  0.57  0.57  0.3   0.4   0.74  0.7   0.5   0.41  0.6   0.41  0.54  0.4
#  0.3   0.5   0.6   0.54  0.5   0.4   0.78  0.3   0.4   0.45  0.57  0.38
#  0.4   0.3   0.4   0.62  0.26  0.46  0.62  0.4   0.5   0.3   0.5   0.7
#  0.3   0.555 0.4   0.5   0.6   0.61  0.6   0.6   0.26  0.5   0.4   0.4
#  0.52  0.78  0.47  0.38  0.5   0.8   0.4   0.5   0.5   0.4   0.55  0.5
#  0.45  0.59  0.5   0.5   1.    0.52  0.45  0.42  0.62  0.6   0.43  0.65
#  0.61  0.4   0.5   0.6   0.93  0.6   0.4   0.41  0.5   0.51  0.38  0.5
#  0.21  0.5   0.3   0.5   0.4   0.52  0.64  0.8   0.62  0.64  0.57  0.83
#  0.78  0.57  0.7   0.3   0.7   0.4   0.5   0.52  0.6   0.6   0.45  0.3
#  0.5   0.52  0.5   0.38  0.5   0.67  0.55  0.41  0.57  0.5   0.65  0.5
#  0.5   0.5   0.4   0.62  0.61  0.5   0.5   0.52  0.38  0.52  0.7   0.58
#  0.57  0.4  ]

# %%
# mse , mae and r2_score values
mae_value = mean_absolute_error(y_val, prediction)
mse_value = mean_squared_error(y_val, prediction)
r2_score_value = r2_score(y_val, prediction)
# Total error with mse , mae and r2_score
print(f"MSE {mse_value}")
print(f"MAE {mae_value}")
print(f"r2_score {r2_score_value}")
# Out:
# MSE 0.03573947368421052
# MAE 0.1276691729323308
# r2_score -0.7258502284781623

# %% [markdown]
# ### Visulization

# %%
plt.plot(prediction,color = 'Blue')
plt.plot(y_val, color = 'red')
plt.title("Decision Tree Regression Model For OM")
plt.legend(['Predicted OM values', 'Actual OM Values'], loc='upper left')
plt.xlabel('PH indexes')
plt.ylabel('OM values')
plt.savefig("DTRmodelForOMestimationUsingpHIndexes.jpg")
