# %% [markdown]
# ### Libraries for dataset manipulation and visulization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Dataset Loading

# %%
dataset = pd.read_csv('C:\\Users\\Mahmood Yousaf\\Desktop\\FYP\\Final-Year-Project-Soil-Analysis-using-machine-learning\\Extracted Features\\P_Index_with_P_value.csv')

# %% [markdown]
# ### Preprocessing on dataset

# %%
X = np.array(dataset['P_Index'])
Y = np.array(dataset['P_Value'])
print(X)
print(Y)
# Out:
# [0.00703939 0.0073076  0.00680586 ... 0.00868003 0.0176074  0.01053636]
# [5.4 5.4 4.8 ... 5.  5.5 5.5]

# %%
X = X.reshape(len(X),1)
Y = Y.reshape(len(Y),1)
print(X,Y)
# Out:
# [[0.00703939]
#  [0.0073076 ]
#  [0.00680586]
#  ...
#  [0.00868003]
#  [0.0176074 ]
#  [0.01053636]] [[5.4]
#  [5.4]
#  [4.8]
#  ...
#  [5. ]
#  [5.5]
#  [5.5]]

# %% [markdown]
# ### DTR model training

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, Y)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %% [markdown]
# ### Prediction

# %%
pred = regressor.predict(X_val)
print(pred)
# Out:
# [4.2  4.8  5.4  8.4  6.   5.5  4.5  6.   4.3  4.8  4.   4.6  4.9  6.2
#  4.8  3.   6.   5.2  3.2  5.6  4.5  4.2  6.   4.8  4.6  5.5  5.6  5.4
#  5.2  4.6  4.7  6.2  8.   4.3  5.   5.2  5.5  4.   5.4  4.5  5.6  4.5
#  6.8  7.2  3.6  5.5  4.1  4.7  5.   4.7  3.7  4.5  6.8  4.7  6.   3.2
#  3.1  7.1  7.5  5.5  4.   4.2  4.8  4.1  5.7  4.   4.   4.8  5.6  4.8
#  5.   4.8  4.   4.5  5.4  4.5  5.1  4.8  4.   5.2  7.5  4.1  4.8  3.8
#  4.   5.6  4.   4.5  5.7  4.3  4.6  5.9  5.6  4.1  4.8  4.3  6.   4.7
#  4.5  9.   4.1  5.2  5.   3.7  4.   5.2  4.2  6.3  4.5  3.8  5.4  4.8
#  4.5  4.   3.1  6.2  4.2  8.8  6.   4.5  4.8  5.3  4.2  5.6  3.2  6.
#  3.2  6.2  5.2  5.   7.5  6.5  4.5  5.   4.   4.8  4.6  4.6  6.   6.2
#  3.7  7.4  4.6  4.2  4.   4.2  5.8  5.6  4.7  3.5  5.8  6.   4.8  5.2
#  5.4  5.85 3.   6.6  3.7  5.3  4.8  4.3  4.6  4.3  4.6  5.4  5.   5.6
#  6.5  4.   7.   4.8  5.8  4.8  5.9  5.6  6.1  6.   5.5  6.6  6.   5.5
#  6.   3.7  5.4  3.2  5.1  5.8  6.6  4.6  5.7  4.6  4.1  6.6  4.6  7.1
#  4.   5.1  6.2  5.5  6.8  5.5  6.   3.6  4.8  6.   4.6  6.   5.1  4.8
#  5.6  6.   5.   4.   7.   8.   6.8  5.1  5.5  3.2  4.5  6.6  4.   6.
#  3.9  5.2  5.5  5.3  5.8  5.1  5.   5.5  4.2  6.6  6.8  4.2  3.1  4.1
#  5.1  5.1  6.   4.8  4.8  4.4  4.8  5.2  5.6  4.8  5.6  4.4  6.5  3.
#  5.5  8.8  6.   4.2  4.6  3.2  3.1  4.   4.8  5.   4.2  5.8  4.2  6.  ]

# %%
# mse , mae and r2_score values
mae_value = mean_absolute_error(y_val, pred)
mse_value = mean_squared_error(y_val, pred)
r2_score_value = r2_score(y_val, pred)
# Total error with mse , mae and r2_score
print(f"MSE {mse_value}")
print(f"MAE {mae_value}")
print(f"r2_score {r2_score_value}")
# Out:
# MSE 2.1533176691729325
# MAE 1.025375939849624
# r2_score -0.5050607570400987

# %% [markdown]
# ### Visulization

# %%
plt.plot(pred,color = 'Blue')
plt.plot(y_val, color = 'red')
plt.title("Decision Tree Regression Model For P")
plt.legend(['Predicted P values', 'Actual P Values'], loc='upper left')
plt.xlabel('PH indexes')
plt.ylabel('P values')
plt.savefig("DTRmodelForPestimationUsingpHIndexes.jpg")
