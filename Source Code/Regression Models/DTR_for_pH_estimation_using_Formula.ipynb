# %% [markdown]
# ### Libraries for dataset manipulation and visulization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Dataset Loading

# %%
dataset = pd.read_csv('C:\\Users\\Mahmood Yousaf\\Desktop\\FYP\\Final-Year-Project-Soil-Analysis-using-machine-learning\\Extracted Features\\Formula_Index_with_pH_value.csv')

# %% [markdown]
# ### Preprocessing on dataset

# %%
X = np.array(dataset['Formula_Index'])
Y = np.array(dataset['pH_Value'])
print(X)
print(Y)
# Out:
# [525.  505.  542.  ... 397.  262.5 365. ]
# [7.9 7.9 7.9 ... 7.7 7.7 7.7]

# %%
X = X.reshape(len(X),1)
Y = Y.reshape(len(Y),1)
print(X,Y)
# Out:
# [[525. ]
#  [505. ]
#  [542. ]
#  ...
#  [397. ]
#  [262.5]
#  [365. ]] [[7.9]
#  [7.9]
#  [7.9]
#  ...
#  [7.7]
#  [7.7]
#  [7.7]]

# %% [markdown]
# ### DTR model training

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, Y)

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %% [markdown]
# ### Prediction

# %%
prediction = regressor.predict([[500]])
print(prediction)
# Out:
# [7.93333333]

# %%
pred = regressor.predict(X_val)
print(pred)
# Out:
# [7.9        7.8        7.7        8.         7.85       7.8
#  7.75       7.83333333 7.8        8.02       7.65       7.625
#  8.05       7.95       7.8        7.85       7.9        7.8
#  7.76666667 7.95       7.925      7.8        7.8        8.
#  7.6        8.05       7.93333333 7.79       8.1        7.8
#  7.9        7.8        7.88333333 8.05       7.9        7.85
#  7.9        7.8        7.9        7.88333333 8.         7.81176471
#  7.7        7.8        7.74285714 7.8        7.8        7.9
#  7.775      7.7875     7.95714286 7.825      7.8        7.9
#  7.7        7.76666667 7.85       7.75       7.8        7.8
#  8.         7.76666667 7.75714286 7.9        7.7        7.85
#  7.5        7.975      7.8        7.975      7.8        7.88571429
#  7.96666667 7.88571429 7.78       7.9        7.91666667 7.6
#  7.75714286 8.1        7.83333333 7.77777778 7.71       7.8
#  7.8        7.925      7.85       8.         7.65       7.76666667
#  7.91666667 7.675      7.925      7.6        7.875      7.8
#  7.76666667 7.85       8.         7.75       7.76666667 7.81176471
#  7.625      7.9        7.96666667 7.76       7.7875     7.74444444
#  7.8        7.85       7.68333333 7.75       8.         7.9
#  8.01       7.6        7.6        7.81176471 7.86666667 7.9
#  7.66666667 7.91666667 8.         7.88       7.83333333 7.7875
#  7.7        7.775      8.2        7.6        7.8        7.75
#  7.6        7.6        7.75714286 7.8        7.73333333 7.65
#  8.         7.85       7.675      7.6        8.2        7.9
#  7.7        7.9        7.8        7.6        7.75       7.9
#  7.625      7.75       7.6        7.76666667 7.75       7.93333333
#  7.95714286 7.75       7.75       7.85       7.88571429 7.75
#  7.96666667 7.7        8.05       7.7        8.05       7.7
#  7.76666667 8.01       7.6        7.87142857 7.9        7.7
#  8.         7.95714286 7.7        7.875      7.66666667 7.975
#  8.         7.775      7.78       7.81176471 7.9        8.
#  7.85       7.825      7.85       7.85       7.7875     7.79
#  7.7875     7.75       7.625      7.65       7.8125     7.7
#  7.825      7.75714286 7.68333333 7.9        7.55       7.74444444
#  7.88333333 7.74444444 7.9        7.72       7.87142857 7.6
#  7.72       7.7        7.96666667 7.7        7.72       7.75
#  8.         7.75       7.96666667 7.6        7.7        7.65
#  7.9        7.6        7.775      7.8        7.8        7.5
#  7.7        8.1        7.8        7.8        7.85       7.85
#  7.86666667 7.6        7.875      7.95       7.88571429 7.66666667
#  7.7        7.95714286 7.7        7.9        7.8        8.
#  7.925      7.7        7.8        7.725      8.         7.95
#  7.79       7.76       7.6        7.8        7.98333333 7.76
#  7.8        7.85       7.8        7.74444444 7.6        7.78
#  8.         7.78      ]

# %% [markdown]
# ### Visulization

# %%
plt.plot(pred,color = 'Blue')
plt.plot(y_val, color = 'red')
plt.title("Decision Tree Regression Model")
plt.legend(['Predicted pH values', 'Actual pH Values'], loc='upper left')
plt.xlabel('Formula indexes')
plt.ylabel('pH values')
plt.savefig("DTRmodelForpHestimationUsingFormula.jpg")

# %%
from sklearn.metrics import r2_score
r2_score(y_val,pred)
# Out:
# -0.32485475318029544
